# %%
import json
import numpy as np
import matplotlib.pyplot as plt

# Load from the file
with open('code/grid_search.json', 'r') as file:
    grid = json.load(file)
# Out:
# file1.txt

# %%
# Out:
# 735
# 75
# 24
# 732
# 718
# 31
# 49
# 63
# 52
# 44

# %%
# plot params as function of flipangle for all tissue types.

import pandas as pd

# Initialize an empty DataFrame
result_df = pd.DataFrame()

# Your loop
for i in range(5):  # Replace 5 with the desired number of iterations
    # Assuming you have a DataFrame to concatenate in each iteration, let's call it df_to_concat
    df_to_concat = pd.DataFrame({
        'Column1': [i],
        'Column2': [i * 2]
    })

    # Concatenate the DataFrame to the result_df
    result_df = pd.concat([result_df, df_to_concat], ignore_index=True)

# Display the final concatenated DataFrame
print(result_df)
# Out:
#    Column1  Column2
# 0        0        0
# 1        1        2
# 2        2        4
# 3        3        6
# 4        4        8
